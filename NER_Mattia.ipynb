# %% [markdown]
# <a href="https://colab.research.google.com/github/mattiapocci/PhilosoperRank/blob/master/NER_Mattia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Imports and Drive Mount***

# %%
#!pip3 install -U spacy[cuda92]
#!python3 -m spacy download en_core_web_lg
#https://stackoverflow.com/questions/54334304/spacy-cant-find-model-en-core-web-sm-on-windows-10-and-python-3-5-3-anacon

import sys
import time
import os
import numpy as np
import random
import json
import spacy
from spacy import displacy
import nltk
import pprint
from nltk.tokenize import word_tokenize

nltk.download('punkt')

nlp = spacy.load("en_core_web_sm")
spacy.prefer_gpu()

from google.colab import drive

drive.mount('/content/drive')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # ***Language Analysis***

# %%
"""
1. X cite(s|d) Y1, Y2, …, Yn as (an) influence(s)
2. X was influenced by Y1, Y2, …, Yn
3. Y has been cited as an influence by X1, X2, …, Xn
4. Y influence on X1, X2, …, Xn …
5. Y1, Y2, …, Yn influenced hi(m|s) …
"""

doc1 = nlp("Mark was influenced by Jhon")
doc2 = nlp("Jhon influenced Mark")
doc3 = nlp("Mark was an influence of Jhon and Albert")
doc4 = nlp("Jhon influenced him")
doc5 = nlp("Adler was also influenced by the philosophies of Immanuel Kant, Friedrich Nietzsche, Rudolf Virchow and the statesman Jan Smuts ")
doc6 = nlp("He is cited as an influence on John Milton")
print("------")
print("1 Mark was influenced by Jhon")
displacy.render(doc1, style="dep", jupyter=True)
print("CHUNKS")
for chunk in doc1.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, 
            chunk.root.head.text)
print("TREE")
for token in doc1:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
    
print("------")
print("2 Jhon influenced Mark")
displacy.render(doc2, style="dep", jupyter=True)
print("CHUNKS")

for chunk in doc2.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, 
            chunk.root.head.text)
print("TREE")
for token in doc2:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
    
print("------")
print("3 Mark was an influence of Jhon and Albert")
displacy.render(doc3, style="dep", jupyter=True)
print("CHUNKS")
    
for chunk in doc3.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, 
            chunk.root.head.text)
print("TREE")
for token in doc3:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
    
print("------")
print("4 Jhon influenced him")
displacy.render(doc4, style="dep", jupyter=True)
print("CHUNKS")
    
for chunk in doc4.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, 
            chunk.root.head.text)
print("TREE")
for token in doc4:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])

print("5 Jhon influenced him")
displacy.render(doc5, style="dep", jupyter=True)
print("CHUNKS")
    
for chunk in doc5.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, 
            chunk.root.head.text)
print("TREE")
for token in doc5:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
    
print("6 Jhon influenced him")
displacy.render(doc5, style="dep", jupyter=True)
print("CHUNKS")
    
for chunk in doc5.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, 
            chunk.root.head.text)
print("TREE")
for token in doc5:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])

    
#print(jsonlist[0]["article"])
#doc = nlp(jsonlist[0]["article"])
# Out:
# ------
# 1 Mark was influenced by Jhon
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ab96b14229584638b881d870c209cef5-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Jhon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab96b14229584638b881d870c209cef5-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab96b14229584638b881d870c209cef5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab96b14229584638b881d870c209cef5-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab96b14229584638b881d870c209cef5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab96b14229584638b881d870c209cef5-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab96b14229584638b881d870c209cef5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">agent</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab96b14229584638b881d870c209cef5-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab96b14229584638b881d870c209cef5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# CHUNKS
# Mark Mark nsubjpass influenced
# Jhon Jhon pobj by
# TREE
# Mark nsubjpass influenced VERB []
# was auxpass influenced VERB []
# influenced ROOT influenced VERB [Mark, was, by]
# by agent influenced VERB [Jhon]
# Jhon pobj by ADP []
# ------
# 2 Jhon influenced Mark
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="20f652b4851d4d019bf2bb713ba62273-0" class="displacy" width="575" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Jhon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-20f652b4851d4d019bf2bb713ba62273-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-20f652b4851d4d019bf2bb713ba62273-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-20f652b4851d4d019bf2bb713ba62273-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-20f652b4851d4d019bf2bb713ba62273-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,91.5 L408.0,79.5 392.0,79.5" fill="currentColor"/>
# </g>
# </svg></span>
# CHUNKS
# Jhon Jhon nsubj influenced
# Mark Mark dobj influenced
# TREE
# Jhon nsubj influenced VERB []
# influenced ROOT influenced VERB [Jhon, Mark]
# Mark dobj influenced VERB []
# ------
# 3 Mark was an influence of Jhon and Albert
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="82db05a806654c58b2772e97edfe362a-0" class="displacy" width="1450" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">influence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Jhon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Albert</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82db05a806654c58b2772e97edfe362a-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82db05a806654c58b2772e97edfe362a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82db05a806654c58b2772e97edfe362a-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82db05a806654c58b2772e97edfe362a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82db05a806654c58b2772e97edfe362a-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82db05a806654c58b2772e97edfe362a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82db05a806654c58b2772e97edfe362a-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82db05a806654c58b2772e97edfe362a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82db05a806654c58b2772e97edfe362a-0-4" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82db05a806654c58b2772e97edfe362a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,179.0 L928.0,167.0 912.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82db05a806654c58b2772e97edfe362a-0-5" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82db05a806654c58b2772e97edfe362a-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,179.0 L1103.0,167.0 1087.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82db05a806654c58b2772e97edfe362a-0-6" stroke-width="2px" d="M945,177.0 C945,2.0 1275.0,2.0 1275.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82db05a806654c58b2772e97edfe362a-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1275.0,179.0 L1283.0,167.0 1267.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# CHUNKS
# Mark Mark nsubj was
# an influence influence attr was
# Jhon Jhon pobj of
# Albert Albert conj Jhon
# TREE
# Mark nsubj was AUX []
# was ROOT was AUX [Mark, influence]
# an det influence NOUN []
# influence attr was AUX [an, of]
# of prep influence NOUN [Jhon]
# Jhon pobj of ADP [and, Albert]
# and cc Jhon PROPN []
# Albert conj Jhon PROPN []
# ------
# 4 Jhon influenced him
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="18f484fe243646e6b84d13584c3b77e7-0" class="displacy" width="575" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Jhon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">him</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18f484fe243646e6b84d13584c3b77e7-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-18f484fe243646e6b84d13584c3b77e7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18f484fe243646e6b84d13584c3b77e7-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-18f484fe243646e6b84d13584c3b77e7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,91.5 L408.0,79.5 392.0,79.5" fill="currentColor"/>
# </g>
# </svg></span>
# CHUNKS
# Jhon Jhon nsubj influenced
# him him dobj influenced
# TREE
# Jhon nsubj influenced VERB []
# influenced ROOT influenced VERB [Jhon, him]
# him dobj influenced VERB []
# 5 Jhon influenced him
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b7a19c852e5340c3afe87dcb3b691d18-0" class="displacy" width="3375" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Adler</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">philosophies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Immanuel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Kant,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Friedrich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Nietzsche,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Rudolf</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Virchow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">statesman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Jan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Smuts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7a19c852e5340c3afe87dcb3b691d18-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7a19c852e5340c3afe87dcb3b691d18-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7a19c852e5340c3afe87dcb3b691d18-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7a19c852e5340c3afe87dcb3b691d18-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7a19c852e5340c3afe87dcb3b691d18-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7a19c852e5340c3afe87dcb3b691d18-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7a19c852e5340c3afe87dcb3b691d18-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7a19c852e5340c3afe87dcb3b691d18-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">agent</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b7a19c852e5340c3afe87dcb3b691d18-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b7a19c852e5340c3afe87dcb3b691d18-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
# CHUNKS
# Adler Adler nsubjpass influenced
# the philosophies philosophies pobj by
# Immanuel Kant Kant pobj of
# Friedrich Nietzsche Nietzsche conj Kant
# Rudolf Virchow Virchow conj Nietzsche
# the statesman statesman conj Virchow
# Jan Smuts Smuts appos statesman
# TREE
# Adler nsubjpass influenced VERB []
# was auxpass influenced VERB []
# also advmod influenced VERB []
# influenced ROOT influenced VERB [Adler, was, also, by]
# by agent influenced VERB [philosophies]
# the det philosophies NOUN []
# philosophies pobj by ADP [the, of]
# of prep philosophies NOUN [Kant]
# Immanuel compound Kant PROPN []
# Kant pobj of ADP [Immanuel, ,, Nietzsche]
# , punct Kant PROPN []
# Friedrich compound Nietzsche PROPN []
# Nietzsche conj Kant PROPN [Friedrich, ,, Virchow]
# , punct Nietzsche PROPN []
# Rudolf compound Virchow PROPN []
# Virchow conj Nietzsche PROPN [Rudolf, and, statesman]
# and cc Virchow PROPN []
# the det statesman NOUN []
# statesman conj Virchow PROPN [the, Smuts]
# Jan compound Smuts PROPN []
# Smuts appos statesman NOUN [Jan]
# 6 Jhon influenced him
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2cad470587174f0489a2e9049f0362e9-0" class="displacy" width="3375" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Adler</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">philosophies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Immanuel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Kant,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Friedrich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Nietzsche,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Rudolf</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Virchow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">statesman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Jan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Smuts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2cad470587174f0489a2e9049f0362e9-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2cad470587174f0489a2e9049f0362e9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2cad470587174f0489a2e9049f0362e9-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2cad470587174f0489a2e9049f0362e9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2cad470587174f0489a2e9049f0362e9-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2cad470587174f0489a2e9049f0362e9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2cad470587174f0489a2e9049f0362e9-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2cad470587174f0489a2e9049f0362e9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">agent</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2cad470587174f0489a2e9049f0362e9-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2cad470587174f0489a2e9049f0362e9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
# CHUNKS
# Adler Adler nsubjpass influenced
# the philosophies philosophies pobj by
# Immanuel Kant Kant pobj of
# Friedrich Nietzsche Nietzsche conj Kant
# Rudolf Virchow Virchow conj Nietzsche
# the statesman statesman conj Virchow
# Jan Smuts Smuts appos statesman
# TREE
# Adler nsubjpass influenced VERB []
# was auxpass influenced VERB []
# also advmod influenced VERB []
# influenced ROOT influenced VERB [Adler, was, also, by]
# by agent influenced VERB [philosophies]
# the det philosophies NOUN []
# philosophies pobj by ADP [the, of]
# of prep philosophies NOUN [Kant]
# Immanuel compound Kant PROPN []
# Kant pobj of ADP [Immanuel, ,, Nietzsche]
# , punct Kant PROPN []
# Friedrich compound Nietzsche PROPN []
# Nietzsche conj Kant PROPN [Friedrich, ,, Virchow]
# , punct Nietzsche PROPN []
# Rudolf compound Virchow PROPN []
# Virchow conj Nietzsche PROPN [Rudolf, and, statesman]
# and cc Virchow PROPN []
# the det statesman NOUN []
# statesman conj Virchow PROPN [the, Smuts]
# Jan compound Smuts PROPN []
# Smuts appos statesman NOUN [Jan]

# %% [markdown]
# #***Import JSON articles***

# %%
"""
{
    "philosopher": "name",
    "article": "plaintext_article",
    "pageid": "id",
    "table_influenced": 
        [
            {
                "0": "name_of_someone_philosopher_influenced_by"
            }
        ]
    "table_influences":
        [
            {
                "0": "name_of_someone_philosopher_influences"
            }
        ]
}
"""
#open the file
with open('/content/drive/My Drive/folder/result_1.json') as f:
  jsonlist = json.load(f)

# %% [markdown]
# # ***Text Preprocessing***

# %%
"""
#HIM
#divide in sentences the article

#eliminate sentences that don't include influenc -e, -ed, -es, -ing etc

#pattern matching on patterns (see language analysis)

#Entity recognition and recostruction

#US
"mark influenced jhon. Today is friday"
#divide in sentences the article
"mark influenced jhon"
"Today is friday"
#eliminate sentences that don't include influenc -e, -ed, -es, etc
"mark influenced jhon"

#pattern matching on patterns (using spacy 
?)
[x = "mark", y = "jhon"]

#Entity recognition and recostruction(here we have a proble, when he had Hendrix he could )
"""
import time
start = time.time()

for elem in jsonlist:
    #divide in sentences the article
    sent_list = nltk.sent_tokenize(elem["article"])
    
    sent_list = [word_tokenize(i) for i in sent_list]

    influence_list = []
    influence_declinations = ["influence", "influenced", "influences", "influencing"]

    for word_list in sent_list:
        temp = [x for x in word_list if x in influence_declinations]
        if len(temp) != 0:
            influence_list.append(' '.join(word for word in word_list))

    new_list = []
    for sent in influence_list:
        new_list.append(sent)
        #displacy.render(sent, style="dep", jupyter=True)
    elem["article"] = new_list

print(time.time() - start)
# Out:
# 41.28778696060181

# %% [markdown]
# # ***Processing Giuliano(Spacy Dependencies)***

# %%
"""
Input cella:
jsonlist = 
[
    {
        "philosopher" = "philosopher_name",
        "pageid" = id,
        "article" = 
        [
            "frase contenente influence",

            "frase contenente influence", etc
        ]
    }
]

Output cella:
output =
[
    {
        "philosopher" = "philosopher_name",
        "pageid" = id,
        "article" = 
        [
            [
                "frase contenente influence",
                [
                    list of influencers
                ],
                [
                    list of influenced
                ]
        ]
    }
]
"""


def display_info(list_of_sentences):
    print("------")
    for sent in list_of_sentences:
        print(sent)
        doc = nlp(sent)
        displacy.render(doc, style="dep", jupyter=True)
        print("CHUNKS")

        for chunk in doc.noun_chunks:
            print(chunk.text, chunk.root.text, chunk.root.dep_, 
                    chunk.root.head.text)
        print("TREE")
        for token in doc:
            print(token.text, token.dep_, token.head.text, token.head.pos_,
                    [child for child in token.children])
"""
#some prints and infos

#pprint.pprint(jsonlist)
print(len(jsonlist))
jsonlist_no_empty = [i for i in jsonlist if len(i["article"]) != 0]
print(len(jsonlist_no_empty))
print([[i["philosopher"], len(i["article"]), i["article"]] for i in jsonlist_no_empty if i["philosopher"] == "Socrates"])
"""
"""
import re
print(jsonlist_no_empty[20]["article"][0])
tokens = [i for i in jsonlist_no_empty[20]["article"][0] if i.isupper() ]
print(tokens)
"""

for phil in jsonlist_no_empty:
    display_info(phil["article"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-45e10fdbe486> in <module>()
#      69 """
#      70
# ---> 71 for phil in jsonlist_no_empty:
#      72     display_info(phil["article"])
#      73
#
# NameError: name 'jsonlist_no_empty' is not defined

# %% [markdown]
# # ***Processing Mattia(Regex)***

# %%
import re
"""
Input cella:
jsonlist = 
[
    {
        "philosopher" = "philosopher_name",
        "pageid" = id,
        "article" = 
        [
            "frase contenente influence",

            "frase contenente influence", etc
        ]
    }
]

Output cella:
output =
[
    {
        "philosopher" = "philosopher_name",
        "pageid" = id,
        "article" = 
        [
            [
                "frase contenente influence",
                [
                    list of influencers
                ],
                [
                    list of influenced
                ]
        ]
    }
]
"""

"""
#some prints and infos

pprint.pprint(jsonlist)
print(len(jsonlist))
jsonlist_no_empty = [i for i in jsonlist if len(i["article"]) != 0]
print(len(jsonlist_no_empty))
print([[i["philosopher"], len(i["article"]), i["article"]] for i in jsonlist_no_empty if i["philosopher"] == "Socrates"])
"""
#pprint.pprint(jsonlist)
stringone = 'His philosophy is mainly influenced by such thinkers as Nietzsche , Epicurus , the Cynic and Cyrenaic schools , as well as French materialism .'
relations = re.findall(r'[A-Z][a-z]+[\s]', stringone)
influence = re.findall(r'[iI]nfluenced[\s]', stringone)
dio = re.findall(r'[A-Z][a-z]+[\s].*[iI]nfluenced[\s].*[A-Za-z]+[\s]', stringone)
left = re.findall(r'[A-Z][a-z]+[\s].*[iI]nfluenced[\s]', stringone)
right = re.findall(r'[iI]nfluenced by[\s].*', stringone)
influencers = re.findall(r'[A-Z][a-z]+[\s]', str(right))
influenced = re.findall(r'[A-Z][a-z]+[\s]', str(left))
print(stringone)
print('Left: ' + str(left))
print('Right: ' + str(right))
print('Influencers: ' + str(influencers))
print('Influenced: ' + str(influenced))



jsonlist_no_empty = [i for i in jsonlist if len(i["article"]) != 0]

for pippo in jsonlist_no_empty:
  print(len(pippo['article']))
  for i in range(len(pippo['article'])):
    #cosa fare su ogni singola frase
    #print(re.split(r'\s',pippo['article'][i]))
    #relations = re.findall(r'[\w\.-]+@[\w\.-]+', pippo['article'][i])
    #relations = re.findall(r'[A-Z][a-z]+[\s]', pippo['article'][i])
    #influence = re.findall(r'[iI]nfluence', pippo['article'][i])
    #dio = re.findall(r'[A-Z][a-z]+[\s][iI]nfluence[\s][A-Za-z]+[\s]', pippo['article'][i])


    left = re.findall(r'[A-Z][a-z]+[\s].*[iI]nfluenced[\s]', pippo['article'][i])
    right = re.findall(r'[iI]nfluenced by[\s].*', pippo['article'][i])
    influencers = re.findall(r'[A-Z][a-z]+[\s]', str(right))
    influenced = re.findall(r'[A-Z][a-z]+[\s]', str(left))


    #print('Relations: ' + str(relations))
    #print('Influence: ' + str(influence))
    #print('Dio: ' + str(dio))

    print('Left: ' + str(left))
    print('Right: ' + str(right))
    print('Influencers: ' + str(influencers))
    print('Influenced: ' + str(influenced))

  #print(re.split('\s',pippo['article'][0]))
# Out:
# Streaming output truncated to the last 5000 lines.
# Right: []
# Influencers: []
# Influenced: []
# 8
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['His sympathetic nature was influenced ']
# Right: ['influenced by indignation against the brutal methods adopted towards activists , especially political prisoners , and by the stern measures which the authorities felt compelled to adopt in order to repress the revolutionary movement .']
# Influencers: []
# Influenced: ['His ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 3
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['His overall theological philosophy was influenced ']
# Right: ['influenced by Adam Wodeham , Gregory of Rimini , Thomas Aquinas , and Bonaventure .']
# Influencers: ['Adam ', 'Wodeham ', 'Gregory ', 'Rimini ', 'Thomas ', 'Aquinas ', 'Bonaventure ']
# Influenced: ['His ']
# Left: ['Also crucial to his theological studies are his thoughts regarding a version of divine simplicity—of which he was highly influenced ']
# Right: ['influenced by Wodeham .']
# Influencers: ['Wodeham ']
# Influenced: ['Also ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: ['His prose was extensively read and influenced ']
# Right: []
# Influencers: []
# Influenced: ['His ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 3
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Also known as 'animal magnetism ' , it can be defined as a `` loosely grouped set of practices in which one person influenced "]
# Right: []
# Influencers: []
# Influenced: ['Also ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['Legacy == The Prague School linguists were influenced ']
# Right: ['influenced by his works .']
# Influencers: []
# Influenced: ['Legacy ', 'The ', 'Prague ', 'School ']
# 3
# Left: ['He wrote De institutione bene vivendi per exempla sanctorum , a moralist tractate of Biblical inspiration which he managed to publish in 1506 in Venice ; this work influenced ']
# Right: []
# Influencers: []
# Influenced: ['He ', 'De ', 'Biblical ', 'Venice ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["This Marulić 's work influenced "]
# Right: []
# Influencers: []
# Influenced: ['This ']
# 16
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Many intellectuals , labour unions , artists and political parties worldwide have been influenced ']
# Right: ["influenced by Marx 's work , with many modifying or adapting his ideas ."]
# Influencers: ['Marx ']
# Influenced: ['Many ']
# Left: ['Although critical of Bauer , Marx was increasingly influenced ']
# Right: ['influenced by the ideas of the Young Hegelians Max Stirner and Ludwig Feuerbach , but eventually Marx and Engels abandoned Feuerbachian materialism as well.During the time that he lived at 38 Rue Vanneau in Paris ( from October 1843 until January 1845 ) , Marx engaged in an intensive study of political economy ( Adam Smith , David Ricardo , James Mill , etc .']
# Influencers: ['Young ', 'Hegelians ', 'Max ', 'Stirner ', 'Ludwig ', 'Feuerbach ', 'Marx ', 'Engels ', 'Feuerbachian ', 'During ', 'Rue ', 'Vanneau ', 'Paris ', 'October ', 'January ', 'Marx ', 'Adam ', 'Smith ', 'David ', 'Ricardo ', 'James ', 'Mill ']
# Influenced: ['Although ', 'Bauer ', 'Marx ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['However , by the spring of 1845 his continued study of political economy , capital and capitalism had led Marx to the belief that the new political economic theory that he was espousing – scientific socialism – needed to be built on the base of a thoroughly developed materialistic view of the world.The Economic and Philosophical Manuscripts of 1844 had been written between April and August 1844 , but soon Marx recognised that the Manuscripts had been influenced ']
# Right: ['influenced by some inconsistent ideas of Ludwig Feuerbach .']
# Influencers: ['Ludwig ', 'Feuerbach ']
# Influenced: ['However ', 'Marx ', 'The ', 'Economic ', 'Philosophical ', 'Manuscripts ', 'April ', 'August ', 'Marx ', 'Manuscripts ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Here Marx elaborated his labour theory of value , which had been influenced ']
# Right: ['influenced by Thomas Hodgskin .']
# Influencers: ['Thomas ', 'Hodgskin ']
# Influenced: ['Here ', 'Marx ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 5
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Influence on other philosophers == Damaris Cudworth Masham 's work and correspondence with many of the great philosophers of the Enlightenment may be argued to have influenced "]
# Right: []
# Influencers: []
# Influenced: ['Influence ', 'Damaris ', 'Cudworth ', 'Masham ', 'Enlightenment ']
# Left: ['Most notably , it is surmised that she influenced ']
# Right: []
# Influencers: []
# Influenced: ['Most ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Even though these manuscripts are not believed to have been in Damaris 's possession until the death of her elder brother , John Cudworth ( 1726 ) , the influence of Ralph Cudworth 's ideas upon Locke 's work can not be ignored , and has led some historians to believe that it was Damaris Cudworth Masham herself ( familiar with her father 's works ) who may have influenced "]
# Right: []
# Influencers: []
# Influenced: ['Even ', 'Damaris ', 'John ', 'Cudworth ', 'Ralph ', 'Cudworth ', 'Locke ', 'Damaris ', 'Cudworth ', 'Masham ']
# 10
# Left: ['Mather influenced ']
# Right: []
# Influencers: []
# Influenced: ['Mather ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 6
# Left: ['After Mayr was appointed at the American Museum of Natural History , he influenced ']
# Right: []
# Influencers: []
# Influenced: ['After ', 'Mayr ', 'American ', 'Museum ', 'Natural ', 'History ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Mayr also greatly influenced ']
# Right: []
# Influencers: []
# Influenced: ['Mayr ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: ['His ideas on instinct strongly influenced ']
# Right: []
# Influencers: []
# Influenced: ['His ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 6
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Influences === McDowell 's work has been heavily influenced "]
# Right: ['influenced by , among others , Ludwig Wittgenstein , P. F. Strawson , David Wiggins , and , especially in the case of his later work , Wilfrid Sellars .']
# Influencers: ['Ludwig ', 'Wittgenstein ', 'Strawson ', 'David ', 'Wiggins ', 'Wilfrid ', 'Sellars ']
# Influenced: ['Influences ', 'Dowell ']
# Left: ['Both have been influenced ']
# Right: ["influenced by Richard Rorty , in particular Rorty 's Philosophy and the Mirror of Nature ( 1979 ) ."]
# Influencers: ['Richard ', 'Rorty ', 'Rorty ', 'Philosophy ', 'Mirror ', 'Nature ']
# Influenced: ['Both ']
# 5
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Mead was influenced ']
# Right: []
# Influencers: []
# Influenced: ['Mead ']
# 1
# Left: ['British historian E. H. Carr cites him as an example of a historian whose views are heavily influenced ']
# Right: ['influenced by the Zeitgeist : liberal during the German Empire , discouraged during the interwar period and deeply pessimistic after World War II .']
# Influencers: ['Zeitgeist ', 'German ', 'Empire ', 'World ', 'War ']
# Influenced: ['British ', 'Carr ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Work == === Ontology === Meinong wrote two early essays on David Hume , the first dealing with his theory of abstraction , the second with his theory of relations , and was relatively strongly influenced ']
# Right: ['influenced by British empiricism .']
# Influencers: ['British ']
# Influenced: ['Work ', 'Ontology ', 'Meinong ', 'David ', 'Hume ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 6
# Left: ['Maurice Jean Jacques Merleau-Ponty ( French : [ mɔʁis mɛʁlo pɔ̃ti , moʁ- ] ; 14 March 1908 – 3 May 1961 ) was a French phenomenological philosopher , strongly influenced ']
# Right: ['influenced by Edmund Husserl and Martin Heidegger .']
# Influencers: ['Edmund ', 'Husserl ', 'Martin ', 'Heidegger ']
# Influenced: ['Maurice ', 'Jean ', 'Jacques ', 'Ponty ', 'French ', 'March ', 'May ', 'French ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Despite , or perhaps because of , this view , his work influenced ']
# Right: []
# Influencers: []
# Influenced: ['Despite ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["In addition , Merleau-Ponty 's work has also influenced "]
# Right: []
# Influencers: []
# Influenced: ['In ', 'Ponty ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ["He did so in 1949 when he won a scholarship with the emergence of a Communist state in Hungary.At the university , he affiliated himself to the so-called `` Budapest School '' , a group of Hungarian philosophers who were taught or influenced "]
# Right: ['influenced by Lukács , including Ágnes Heller and György Márkus .']
# Influencers: ['Heller ']
# Influenced: ['He ', 'Communist ', 'At ', 'Budapest ', 'School ', 'Hungarian ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 5
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Liberty ==== John Stuart Mill 's view on liberty , which was influenced "]
# Right: ['influenced by Joseph Priestley and Josiah Warren , is that the individual ought to be free to do as she/he wishes unless she/he harms others .']
# Influencers: ['Joseph ', 'Priestley ', 'Josiah ', 'Warren ']
# Influenced: ['Liberty ', 'John ', 'Stuart ', 'Mill ']
# Left: ['Appleton influenced ']
# Right: []
# Influencers: []
# Influenced: ['Appleton ']
# Left: ["This philosophy has a long tradition , although Mill 's account is primarily influenced "]
# Right: ["influenced by Jeremy Bentham and Mill 's father James Mill ."]
# Influencers: ['Jeremy ', 'Bentham ', 'Mill ', 'James ', 'Mill ']
# Influenced: ['This ', 'Mill ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 9
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['The political ideas of Milton , Locke , Sidney , and James Harrington strongly influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ', 'Milton ', 'Locke ', 'Sidney ', 'James ', 'Harrington ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Johann Jakob Bodmer was very popular ; it influenced ']
# Right: []
# Influencers: []
# Influenced: ['Johann ', 'Jakob ', 'Bodmer ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Literary legacy === Milton 's use of blank verse , in addition to his stylistic innovations ( such as grandiloquence of voice and vision , peculiar diction and phraseology ) influenced "]
# Right: []
# Influencers: []
# Influenced: ['Literary ', 'Milton ']
# 1
# Left: ['He influenced ']
# Right: []
# Influencers: []
# Influenced: ['He ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Bailey 's The Holly and the Horn states that `` Charles Darwin was to some degree influenced "]
# Right: ["influenced by the theories of Monboddo , who deserves the title of Evolutionist more than that of Eccentric . ''"]
# Influencers: ['Monboddo ', 'Evolutionist ', 'Eccentric ']
# Influenced: ['Bailey ', 'The ', 'Holly ', 'Horn ', 'Charles ', 'Darwin ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 9
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Francis Bacon 's Essays , published over a decade later , in 1596 , usually are presumed to be directly influenced "]
# Right: ["influenced by Montaigne 's collection , and Montaigne is cited by Bacon alongside other classical sources in later essays ."]
# Influencers: ['Montaigne ', 'Montaigne ', 'Bacon ']
# Influenced: ['Francis ', 'Bacon ', 'Essays ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Montaigne 's ideas have influenced "]
# Right: []
# Influencers: []
# Influenced: ['Montaigne ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ["In addition to fueling Moore 's own work , the `` Here is one hand '' argument also deeply influenced "]
# Right: []
# Influencers: []
# Influenced: ['In ', 'Moore ', 'Here ']
# 5
# Left: ['It greatly influenced ']
# Right: []
# Influencers: []
# Influenced: ['It ']
# Left: ['Early works influenced ']
# Right: ['influenced by Utopia included New Atlantis by Francis Bacon , Erewhon by Samuel Butler , and Candide by Voltaire .']
# Influencers: ['Utopia ', 'New ', 'Atlantis ', 'Francis ', 'Bacon ', 'Erewhon ', 'Samuel ', 'Butler ', 'Candide ', 'Voltaire ']
# Influenced: ['Early ']
# Left: ['Marxist theoreticians such as Karl Kautsky considered the book a critique of economic and social exploitation in pre-modern Europe and More is claimed to have influenced ']
# Right: []
# Influencers: []
# Influenced: ['Marxist ', 'Karl ', 'Kautsky ', 'Europe ', 'More ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['By this Zelman implies that Utopia influenced ']
# Right: []
# Influencers: []
# Influenced: ['By ', 'Zelman ', 'Utopia ']
# 4
# Left: ['Also interested in what leads to social change , he was a contemporary of the European social theorists Karl Marx and Friedrich Engels , who were influenced ']
# Right: ['influenced by reading his work on social structure and material culture , the influence of technology on progress .']
# Influencers: []
# Influenced: ['Also ', 'European ', 'Karl ', 'Marx ', 'Friedrich ', 'Engels ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Morgan 's work on the social structure and material culture strongly influenced "]
# Right: []
# Influencers: []
# Influenced: ['Morgan ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 3
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['He criticized Ogyū Sorai for his over-valuing of Chinese civilization and thought , although it has been pointed out that his philological methodology was heavily influenced ']
# Right: ["influenced by Sorai 's ."]
# Influencers: ['Sorai ']
# Influenced: ['He ', 'Sorai ', 'Chinese ']
# Left: ['His ideas were influenced ']
# Right: ['influenced by the Chinese intellectual Wang Yangming ( Ō Yōmei in Japanese ) , who had argued for innate knowing , that mankind had a naturally intuitive ( as opposed to rational ) ability to distinguish good and evil .']
# Influencers: ['Chinese ', 'Wang ', 'Yangming ', 'Japanese ']
# Influenced: ['His ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Broackes also notes that Murdoch 's influence on the discipline of philosophy was sometimes indirect , since it impacted both her contemporaries and the following generation of philosophers , particularly Elizabeth Anscombe , Philippa Foot , John McDowell , and Bernard Williams.Her philosophical work was influenced "]
# Right: ["influenced by Simone Weil ( from whom she borrows the concept of 'attention ' ) , and by Plato , under whose banner she claimed to fight ."]
# Influencers: ['Simone ', 'Weil ', 'Plato ']
# Influenced: ['Broackes ', 'Murdoch ', 'Elizabeth ', 'Anscombe ', 'Philippa ', 'Foot ', 'John ', 'Dowell ', 'Bernard ', 'Her ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: ["In the Vigrahavyavartani Karika , Nāgārjuna criticises the Nyaya theory of pramanas ( means of knowledge ) Nāgārjuna was fully acquainted with the classical Hindu philosophies of Samkhya and even the Vaiseshika.Because of the high degree of similarity between Nāgārjuna 's philosophy and Pyrrhonism , particularly the surviving works of Sextus Empiricus , Thomas McEvilley suspects that Nāgārjuna was influenced "]
# Right: ['influenced by Greek Pyrrhonists texts imported into India .']
# Influencers: ['Greek ', 'Pyrrhonists ', 'India ']
# Influenced: ['In ', 'Vigrahavyavartani ', 'Karika ', 'Nyaya ', 'Hindu ', 'Samkhya ', 'Because ', 'Pyrrhonism ', 'Sextus ', 'Empiricus ', 'Thomas ', 'Evilley ']
# Left: ['But according to others , Pyrrho of Elis ( c. 360-c. 270 BCE ) , usually credited with founding this school of sceptical philosophy , was himself influenced ']
# Right: ["influenced by Indian philosophy , when he travelled to India with Alexander the Great 's army and studied with the gymnosophists ."]
# Influencers: ['Indian ', 'India ', 'Alexander ', 'Great ']
# Influenced: ['But ', 'Pyrrho ', 'Elis ']
# 2
# Left: ['The therapeutic or deflationary philosopher , influenced ']
# Right: ["influenced by the later philosophy of Ludwig Wittgenstein , reconciles people to the dependence of our worldview on our `` form of life '' ."]
# Influencers: ['Ludwig ', 'Wittgenstein ']
# Influenced: ['The ']
# Left: ['Part of the puzzlement here is because of the limitations of imagination : influenced ']
# Right: ['influenced by his Princeton colleague , Saul Kripke , Nagel believes that any type identity statement that identifies a physical state type with a mental state type would be , if true , necessarily true .']
# Influencers: ['Princeton ', 'Saul ', 'Kripke ', 'Nagel ']
# Influenced: ['Part ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['See also == List of thinkers influenced ']
# Right: ['influenced by deconstruction == References == == Further reading == Alexandrova , Alena , ed .']
# Influencers: ['References ', 'Further ', 'Alexandrova ', 'Alena ']
# Influenced: ['See ', 'List ']
# 6
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['It also influenced ']
# Right: []
# Influencers: []
# Influenced: ['It ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['He also influenced ']
# Right: []
# Influencers: []
# Influenced: ['He ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ["He devised the Grelling–Nelson paradox in 1908 and the related idea of autological words with Kurt Grelling.Neo-Friesian subsequently became an influencer in fields of both philosophy and mathematics , as Nelson 's close contacts with scientists and mathematicians influenced "]
# Right: []
# Influencers: []
# Influenced: ['He ', 'Nelson ', 'Kurt ', 'Friesian ', 'Nelson ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['The John von Neumann Award of the Rajk László College for Advanced Studies was named in his honor , and has been given every year since 1995 to professors who have made an outstanding contribution to the exact social sciences and through their work have strongly influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ', 'John ', 'Neumann ', 'Award ', 'Rajk ', 'College ', 'Advanced ', 'Studies ']
# 1
# Left: ['In particular , Neurath , influenced ']
# Right: []
# Influencers: []
# Influenced: ['In ', 'Neurath ']
# 7
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 6
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Many of these beliefs had an influence on the various religious schools which , in turn , influenced ']
# Right: []
# Influencers: []
# Influenced: ['Many ']
# Left: ['Among these beliefs were the existence of kami , indigenous gods and goddesses or protective forces , that influenced ']
# Right: []
# Influencers: []
# Influenced: ['Among ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['His views have been compared to those of David Hume , but it has been suggested that the similarities are superficial , and there is no evidence Nicholas influenced ']
# Right: []
# Influencers: []
# Influenced: ['His ', 'David ', 'Hume ', 'Nicholas ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Nonetheless , there was no Cusan school , and his works were largely unknown until the nineteenth century , though Giordano Bruno quoted him , while some thinkers , like Gottfried Leibniz , were thought to have been influenced ']
# Right: ['influenced by him .']
# Influencers: []
# Influenced: ['Nonetheless ', 'Cusan ', 'Giordano ', 'Bruno ', 'Gottfried ', 'Leibniz ']
# 3
# Left: ['He influenced ']
# Right: []
# Influencers: []
# Influenced: ['He ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 15
# Left: ['His work has also significantly influenced ']
# Right: []
# Influencers: []
# Influenced: ['His ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['He studied at Eden Theological Seminary in Webster Groves , Missouri , where , as he admitted , he was deeply influenced ']
# Right: ["influenced by Samuel D. Press in `` biblical and systematic subjects '' , and Yale Divinity School , where he earned a Bachelor of Divinity degree in 1914 and a Master of Arts degree the following year , with the thesis The Contribution of Christianity to the Doctrine of Immortality ."]
# Influencers: ['Samuel ', 'Press ', 'Yale ', 'Divinity ', 'School ', 'Bachelor ', 'Divinity ', 'Master ', 'Arts ', 'The ', 'Contribution ', 'Christianity ', 'Doctrine ', 'Immortality ']
# Influenced: ['He ', 'Eden ', 'Theological ', 'Seminary ', 'Webster ', 'Groves ', 'Missouri ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['While teaching theology at Union Theological Seminary , Niebuhr influenced ']
# Right: []
# Influencers: []
# Influenced: ['While ', 'Union ', 'Theological ', 'Seminary ', 'Niebuhr ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['His ideas influenced ']
# Right: []
# Influencers: []
# Influenced: ['His ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 27
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["In addition , Ludwig Feuerbach 's The Essence of Christianity influenced "]
# Right: []
# Influencers: []
# Influenced: ['In ', 'Ludwig ', 'Feuerbach ', 'The ', 'Essence ', 'Christianity ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['He also began a friendship with Paul Rée , who in 1876 influenced ']
# Right: []
# Influencers: []
# Influenced: ['He ', 'Paul ']
# Left: ["With the publication in 1878 of Human , All Too Human ( a book of aphorisms ranging from metaphysics to morality to religion ) , a new style of Nietzsche 's work became clear , highly influenced "]
# Right: ["influenced by Afrikan Spir 's Thought and Reality and reacting against the pessimistic philosophy of Wagner and Schopenhauer ."]
# Influencers: ['Afrikan ', 'Spir ', 'Thought ', 'Reality ', 'Wagner ', 'Schopenhauer ']
# Influenced: ['With ', 'Human ', 'All ', 'Too ', 'Human ', 'Nietzsche ']
# Left: ['Painter Mark Rothko was influenced ']
# Right: ["influenced by Nietzsche 's view of tragedy , which were presented in The Birth of Tragedy ."]
# Influencers: ['Nietzsche ', 'The ', 'Birth ', 'Tragedy ']
# Influenced: ['Painter ', 'Mark ', 'Rothko ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['The organicism of Paul Bourget influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ', 'Paul ', 'Bourget ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Hippolyte Taine influenced ']
# Right: []
# Influencers: []
# Influenced: ['Hippolyte ', 'Taine ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['He also quotes Mahler himself , and adds that he was influenced ']
# Right: ["influenced by Nietzsche 's conception and affirmative approach to nature , which Mahler presented in his Third Symphony using Zarathustra 's roundelay ."]
# Influencers: ['Nietzsche ', 'Mahler ', 'Third ', 'Symphony ', 'Zarathustra ']
# Influenced: ['He ', 'Mahler ']
# Left: ['Famous writers and poets influenced ']
# Right: ['influenced by Nietzsche include André Gide , August Strindberg , Robinson Jeffers , Pío Baroja , D.H. Lawrence , Edith Södergran and Yukio Mishima .']
# Influencers: ['Nietzsche ', 'Gide ', 'August ', 'Strindberg ', 'Robinson ', 'Jeffers ', 'Baroja ', 'Lawrence ', 'Edith ', 'Yukio ', 'Mishima ']
# Influenced: ['Famous ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Olaf Stapledon was influenced ']
# Right: ['influenced by the idea of the Übermensch and it is a central theme in his books Odd John and Sirius .']
# Influencers: ['Odd ', 'John ', 'Sirius ']
# Influenced: ['Olaf ', 'Stapledon ']
# Left: ['In Russia , Nietzsche has influenced ']
# Right: []
# Influencers: []
# Influenced: ['In ', 'Russia ', 'Nietzsche ']
# Left: ["Eugene O'Neill remarked that Zarathustra influenced "]
# Right: []
# Influencers: []
# Influenced: ['Eugene ', 'Neill ', 'Zarathustra ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Nietzsche has influenced ']
# Right: []
# Influencers: []
# Influenced: ['Nietzsche ']
# Left: ['Carl Jung was also influenced ']
# Right: ['influenced by Nietzsche .']
# Influencers: ['Nietzsche ']
# Influenced: ['Carl ', 'Jung ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 5
# Left: ['German Roman Catholic priest by the name of George Fischer was said to have profoundly influenced ']
# Right: []
# Influencers: []
# Influenced: ['German ', 'Roman ', 'Catholic ', 'George ', 'Fischer ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 6
# Left: ['Literary and philosophical connections === In the period 1795–1796 , Novalis concerned himself with the philosophical doctrine of Johann Gottlieb Fichte , which greatly influenced ']
# Right: []
# Influencers: []
# Influenced: ['Literary ', 'In ', 'Novalis ', 'Johann ', 'Gottlieb ', 'Fichte ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Novalis influenced ']
# Right: []
# Influencers: []
# Influenced: ['Novalis ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 3
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: ['The views on monarchical accountability espoused in his Dialogus ( written between 1332 and 1347 ) greatly influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ', 'Dialogus ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: ['In this he was highly influenced ']
# Right: ['influenced by the Ancient Rhetoric school of the Ming period , which was a neoclassical movement that saw the Qin and Han periods as the model for prose , and the Tang period for poetry .']
# Influencers: ['Ancient ', 'Rhetoric ', 'Ming ', 'Qin ', 'Han ', 'Tang ']
# Influenced: ['In ']
# Left: ['Goi Ranshū believed that Sorai was motivated to surpass Itō Jinsai , another Confucianist who had influenced ']
# Right: []
# Influencers: []
# Influenced: ['Goi ', 'Sorai ', 'Jinsai ', 'Confucianist ']
# 1
# Left: ['His philosophy is mainly influenced ']
# Right: ['influenced by such thinkers as Nietzsche , Epicurus , the Cynic and Cyrenaic schools , as well as French materialism .']
# Influencers: ['Nietzsche ', 'Epicurus ', 'Cynic ', 'Cyrenaic ', 'French ']
# Influenced: ['His ']
# 5
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 6
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['At Marburg , he was influenced ']
# Right: ['influenced by the neo-Kantianism of Hermann Cohen and Paul Natorp , among others .']
# Influencers: ['Kantianism ', 'Hermann ', 'Cohen ', 'Paul ', 'Natorp ']
# Influenced: ['At ', 'Marburg ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Among those strongly influenced ']
# Right: ['influenced by Ortega y Gasset were Luis Buñuel , Manuel García Morente , Joaquín Xirau , Xavier Zubiri , Ignacio Ellacuría , Emilio Komar , José Gaos , Luis Recasens , Manuel Granell , Francisco Ayala , María Zambrano , Agustín Basave , Máximo Etchecopar , Pedro Laín Entralgo , José Luis López-Aranguren , Julián Marías , John Lukacs , Pierre Bourdieu , Paulino Garagorri , Olavo de Carvalho , Vicente Ferreira da Silva , Vilém Flusser and Félix Martí-Ibáñez .']
# Influencers: ['Ortega ', 'Gasset ', 'Luis ', 'Manuel ', 'Morente ', 'Xirau ', 'Xavier ', 'Zubiri ', 'Ignacio ', 'Emilio ', 'Komar ', 'Gaos ', 'Luis ', 'Recasens ', 'Manuel ', 'Granell ', 'Francisco ', 'Ayala ', 'Zambrano ', 'Basave ', 'Etchecopar ', 'Pedro ', 'Entralgo ', 'Luis ', 'Aranguren ', 'John ', 'Lukacs ', 'Pierre ', 'Bourdieu ', 'Paulino ', 'Garagorri ', 'Olavo ', 'Carvalho ', 'Vicente ', 'Ferreira ', 'Silva ', 'Flusser ']
# Influenced: ['Among ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: ['His work in color theory was influenced by that of Albert Henry Munsell , and in turn influenced ']
# Right: ['influenced by that of Albert Henry Munsell , and in turn influenced Paul Klee and members of De Stijl , including Piet Mondrian .']
# Influencers: ['Albert ', 'Henry ', 'Munsell ', 'Paul ', 'Klee ', 'De ', 'Stijl ', 'Piet ', 'Mondrian ']
# Influenced: ['His ', 'Albert ', 'Henry ', 'Munsell ']
# Left: ["Ostwald 's Monism influenced "]
# Right: []
# Influencers: []
# Influenced: ['Ostwald ', 'Monism ']
# 10
# Left: ['Thought == === Influences === In his early years Otto was most influenced ']
# Right: ['influenced by the German idealist theologian and philosopher Friedrich Schleiermacher and his conceptualization of the category of the religious as a type of emotion or consciousness irreducible to ethical or rational epistemologies .']
# Influencers: ['German ', 'Friedrich ', 'Schleiermacher ']
# Influenced: ['Thought ', 'Influences ', 'In ', 'Otto ']
# Left: ['He felt intuition was valuable in rational domains like mathematics , but subject to the corrective of reason , whereas religious intuitions might not be subject to that corrective.These two early works were influenced ']
# Right: ['influenced by the rationalist approaches of Immanuel Kant and Jakob Fries .']
# Influencers: ['Immanuel ', 'Kant ', 'Jakob ', 'Fries ']
# Influenced: ['He ', 'These ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['More recently , Otto has also influenced ']
# Right: []
# Influencers: []
# Influenced: ['More ', 'Otto ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Aldous Huxley , a major proponent of perennialism , was influenced ']
# Right: ['influenced by Otto ; in The Doors of Perception he writes : The literature of religious experience abounds in references to the pains and terrors overwhelming those who have come , too suddenly , face to face with some manifestation of the mysterium tremendum .']
# Influencers: ['Otto ', 'The ', 'Doors ', 'Perception ', 'The ']
# Influenced: ['Aldous ', 'Huxley ']
# Left: ['Ninian Smart , who was a formative influence on religious studies as a secular discipline , was influenced ']
# Right: ['influenced by Otto in his understanding of religious experience and his approach to understanding religion cross-culturally .']
# Influencers: ['Otto ']
# Influenced: ['Ninian ', 'Smart ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 5
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Paine 's critique of institutionalized religion and advocacy of rational thinking influenced "]
# Right: []
# Influencers: []
# Influenced: ['Paine ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ["Paley 's views influenced "]
# Right: []
# Influencers: []
# Influenced: ['Paley ']
# 1
# Left: ['It is heavily influenced ']
# Right: ['influenced by Schlink , who proposed a distinction between analogical truth , i.e .']
# Influencers: ['Schlink ']
# Influenced: ['It ']
# 1
# Left: ['Papini met William James and Henri Bergson , who greatly influenced ']
# Right: []
# Influencers: []
# Influenced: ['Papini ', 'William ', 'James ', 'Henri ', 'Bergson ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 4
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Pareto 's elite theory also influenced "]
# Right: []
# Influencers: []
# Influenced: ['Pareto ']
# Left: ['Other liberals influenced ']
# Right: ['influenced by Pareto include Norberto Bobbio and Raymond Aron .']
# Influencers: ['Pareto ', 'Norberto ', 'Bobbio ', 'Raymond ', 'Aron ']
# Influenced: ['Other ']
# Left: ["His `` tastes-and-obstacles '' approach to general equilibrium theory was resurrected during the great `` Paretian Revival '' of the 1930s and has influenced "]
# Right: []
# Influencers: []
# Influenced: ['His ', 'Paretian ', 'Revival ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["In an 1850 speech , Parker used the phrase , `` A democracy—of all the people , by all the people , for all the people ; '' which later influenced "]
# Right: []
# Influencers: []
# Influenced: ['In ', 'Parker ']
# 5
# Left: ["He is thought to have been in his prime ( or `` floruit '' ) around 475 BC.Parmenides has been considered the founder of metaphysics or ontology and has influenced "]
# Right: []
# Influencers: []
# Influenced: ['He ', 'Parmenides ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Parmenides ' considerable influence on the thinking of Plato is undeniable , and in this respect Parmenides has influenced "]
# Right: []
# Influencers: []
# Influenced: ['Parmenides ', 'Plato ', 'Parmenides ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 6
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Pascal 's use of humor , mockery , and vicious satire in his arguments made the letters ripe for public consumption , and influenced "]
# Right: []
# Influencers: []
# Influenced: ['Pascal ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['His use of satire and wit influenced ']
# Right: []
# Influencers: []
# Influenced: ['His ']
# 1
# Left: ['Pastore then turned to philosophy , influenced ']
# Right: ["influenced by the works of Pasquale d'Ercole , Friedrich Kiesow , Antonio Garbasso , and Giuseppe Peano , publishing his own thesis Sopra le teorie della scienza : logica , matematica , fisica ( On the theories of science : logic , mathematics , physics ) in 1903 ."]
# Influencers: ['Pasquale ', 'Ercole ', 'Friedrich ', 'Kiesow ', 'Antonio ', 'Garbasso ', 'Giuseppe ', 'Peano ', 'Sopra ', 'On ']
# Influenced: ['Pastore ']
# 4
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Among art critics influenced ']
# Right: ["influenced by Pater were Bernard Berenson , Roger Fry , Kenneth Clark and Richard Wollheim : among early literary Modernists , Marcel Proust , James Joyce , W. B. Yeats , Paul Valéry , Ezra Pound , T. S. Eliot and Wallace Stevens ; and Pater 's influence can be traced in the subjective , stream-of-consciousness novels of the early 20th century ."]
# Influencers: ['Pater ', 'Bernard ', 'Berenson ', 'Roger ', 'Fry ', 'Kenneth ', 'Clark ', 'Richard ', 'Wollheim ', 'Modernists ', 'Marcel ', 'Proust ', 'James ', 'Joyce ', 'Yeats ', 'Paul ', 'Ezra ', 'Pound ', 'Eliot ', 'Wallace ', 'Stevens ', 'Pater ']
# Influenced: ['Among ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['Biological molecules === In the mid-1930s , Pauling , strongly influenced ']
# Right: ["influenced by the biologically oriented funding priorities of the Rockefeller Foundation 's Warren Weaver , decided to strike out into new areas of interest ."]
# Influencers: ['Rockefeller ', 'Foundation ', 'Warren ', 'Weaver ']
# Influenced: ['Biological ', 'In ', 'Pauling ']
# 1
# Left: ['Paul was also simultaneously influenced ']
# Right: ['influenced by other thinkers of the Scholastic period , including the Dominican thinkers Albert the Great and Thomas Aquinas , and his fellow Augustinian , Giles of Rome .']
# Influencers: ['Scholastic ', 'Dominican ', 'Albert ', 'Great ', 'Thomas ', 'Aquinas ', 'Augustinian ', 'Giles ', 'Rome ']
# Influenced: ['Paul ']
# 3
# Left: ['The principles underlying classical conditioning have influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["The British philosopher Bertrand Russell observed that `` [ w ] hether Pavlov 's method 's can be made to cover the whole of human behaviour is open to question , but at any rate they cover a very large field and within this field they have shown how to apply scientific methods with quantitative exactitude '' .Pavlov 's research on conditional reflexes greatly influenced "]
# Right: []
# Influencers: []
# Influenced: ['The ', 'British ', 'Bertrand ', 'Russell ', 'Pavlov ', 'Pavlov ']
# 3
# Left: ['Peckham also studied optics and astronomy , and his studies in those subjects were particularly influenced ']
# Right: ['influenced by Roger Bacon and Alhazen.In around 1270 , Peckham returned to England , where he taught at the University of Oxford , and was elected the provincial minister of England ( Minoriten ) in 1275 .']
# Influencers: ['Roger ', 'Bacon ', 'In ', 'Peckham ', 'England ', 'University ', 'Oxford ', 'England ', 'Minoriten ']
# Influenced: ['Peckham ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['In the field of optics , Peckham was influenced ']
# Right: ['influenced by Euclid , Pseudo-Euclid , Aristotle , Augustine , al-Kindi , Avicenna , Alhazen , Grosseteste , and Roger Bacon .']
# Influencers: ['Euclid ', 'Euclid ', 'Aristotle ', 'Augustine ', 'Kindi ', 'Avicenna ', 'Alhazen ', 'Grosseteste ', 'Roger ', 'Bacon ']
# Influenced: ['In ', 'Peckham ']
# 5
# Left: ['His 1938 Logic : The Theory of Inquiry is much influenced ']
# Right: ['influenced by Peirce .']
# Influencers: ['Peirce ']
# Influenced: ['His ', 'Logic ', 'The ', 'Theory ', 'Inquiry ']
# Left: ['In mathematics , it influenced ']
# Right: []
# Influencers: []
# Influenced: ['In ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['He led a group of doctors to supervise textile mills , their report influenced ']
# Right: []
# Influencers: []
# Influenced: ['He ']
# 6
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 3
# Left: ['Under his guidance the Institute grew fast and considerably influenced ']
# Right: []
# Influencers: []
# Influenced: ['Under ', 'Institute ']
# Left: ['With this and his subsequent publications he significantly influenced ']
# Right: []
# Influencers: []
# Influenced: ['With ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ["According to Miodrag Cekić , Petronijević 's works in philosophy may have influenced "]
# Right: []
# Influencers: []
# Influenced: ['According ', 'Miodrag ']
# 6
# Left: ['Montenegro and Serbia , as well in neighboring countries , and his works have influenced ']
# Right: []
# Influencers: []
# Influenced: ['Montenegro ', 'Serbia ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["His most famous works are Luča mikrokozma , Gorski vijenac and Lažni car Šćepan mali , all epic poems.The historian Zdenko Zlatar argues that Njegoš 's mentor ( and later secretary ) Sima Milutinović influenced "]
# Right: []
# Influencers: []
# Influenced: ['His ', 'Gorski ', 'The ', 'Zdenko ', 'Zlatar ', 'Sima ']
# Left: ['The linguist Vuk Karadžić influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ', 'Vuk ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 3
# Left: ["Some scholars hold that his concept of the Logos as God 's creative principle influenced "]
# Right: []
# Influencers: []
# Influenced: ['Some ', 'Logos ', 'God ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['His ethics were strongly influenced ']
# Right: ["influenced by Aristotelianism and Stoicism , preferring a morality of virtues without passions , such as lust/desire and anger , but with a `` common human sympathy '' ."]
# Influencers: ['Aristotelianism ', 'Stoicism ']
# Influenced: ['His ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 5
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Some of his works continued to circulate in Europe in Greek or Latin versions and influenced ']
# Right: []
# Influencers: []
# Influenced: ['Some ', 'Europe ', 'Greek ', 'Latin ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Concerning the discussion of space , Philoponus ’ claim that from every point in space is possible to draw identical figures , made him be perceived as an innovative thinker who influenced ']
# Right: []
# Influencers: []
# Influenced: ['Concerning ', 'Philoponus ']
# 9
# Left: ['The researcher believed that the way clinical examinations were conducted influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['These discussions led to the development of the Alto prototype , which explored for the first time all the elements of the graphical user interface ( GUI ) , and influenced ']
# Right: []
# Influencers: []
# Influenced: ['These ', 'Alto ']
# Left: ['Thelen and colleagues also found that various other factors also influenced ']
# Right: []
# Influencers: []
# Influenced: ['Thelen ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 5
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Disputationes is influenced ']
# Right: ["influenced by the arguments against astrology espoused by one of his intellectual heroes , Augustine of Hippo , and also by the medieval philosophical tale Ḥayy ibn Yaqẓān by ibn Tufail , which promoted autodidacticism as a philosophical program.Pico 's antagonism to astrology seems to derive mainly from the conflict of astrology with Christian notions of free will ."]
# Influencers: ['Augustine ', 'Hippo ', 'Tufail ', 'Pico ', 'Christian ']
# Influenced: ['Disputationes ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 14
# Left: ['The so-called Neoplatonism of philosophers like Plotinus and Porphyry influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ', 'Neoplatonism ', 'Plotinus ', 'Porphyry ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Plato had also attended courses of philosophy ; before meeting Socrates , he first became acquainted with Cratylus and the Heraclitean doctrines.Ambrose believed that Plato met Jeremiah in Egypt and was influenced ']
# Right: ['influenced by his ideas .']
# Influencers: []
# Influenced: ['Plato ', 'Socrates ', 'Cratylus ', 'Heraclitean ', 'Ambrose ', 'Plato ', 'Jeremiah ', 'Egypt ']
# Left: ['Influences == === Pythagoras === Although Socrates influenced ']
# Right: []
# Influencers: []
# Influenced: ['Influences ', 'Pythagoras ', 'Although ', 'Socrates ']
# Left: ['It is probable that both were influenced ']
# Right: ['influenced by Orphism , and both believed in metempsychosis , transmigration of the soul .']
# Influencers: ['Orphism ']
# Influenced: ['It ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Heraclitus and Parmenides === The two philosophers Heraclitus and Parmenides , following the way initiated by pre-Socratic Greek philosophers like Pythagoras , depart from mythology and begin the metaphysical tradition that strongly influenced ']
# Right: []
# Influencers: []
# Influenced: ['Heraclitus ', 'Parmenides ', 'The ', 'Heraclitus ', 'Parmenides ', 'Socratic ', 'Greek ', 'Pythagoras ']
# Left: ['These ideas about change and permanence , or becoming and Being , influenced ']
# Right: []
# Influencers: []
# Influenced: ['These ', 'Being ']
# Left: ["Further , he assigned to these two elements respectively the causation of good and of evil '' .The most important aspect of this interpretation of Plato 's metaphysics is the continuity between his teaching and the Neoplatonic interpretation of Plotinus or Ficino which has been considered erroneous by many but may in fact have been directly influenced "]
# Right: ["influenced by oral transmission of Plato 's doctrine ."]
# Influencers: ['Plato ']
# Influenced: ['Further ', 'The ', 'Plato ', 'Neoplatonic ', 'Plotinus ', 'Ficino ']
# Left: ["In his chapter on Plato and the Irrational Soul ... Dodds traces Plato 's spiritual evolution from the pure rationalist of the Protagoras to the transcendental psychologist , influenced "]
# Right: ['influenced by the Pythagoreans and Orphics , of the later works culminating in the Laws .']
# Influencers: ['Pythagoreans ', 'Orphics ', 'Laws ']
# Influenced: ['In ', 'Plato ', 'Irrational ', 'Soul ', 'Dodds ', 'Plato ', 'Protagoras ']
# ...
# Right: ['influenced by Whewell , who persuaded Darwin to become secretary of the Geological Society of London .']
# Influencers: ['Whewell ', 'Darwin ', 'Geological ', 'Society ', 'London ']
# Influenced: ['Among ', 'Whewell ', 'Bridgewater ', 'Treatise ', 'Astronomy ', 'General ', 'Physics ', 'Natural ', 'Theology ', 'Of ', 'Plurality ', 'Worlds ', 'Platonic ', 'Dialogues ', 'English ', 'Readers ', 'Lectures ', 'History ', 'Moral ', 'Philosophy ', 'England ', 'Of ', 'Liberal ', 'Education ', 'General ', 'Leading ', 'Studies ', 'University ', 'Cambridge ', 'Hugo ', 'Grotius ', 'De ', 'Mathematical ', 'Works ', 'Isaac ', 'Barrow ', 'Whewell ', 'Cambridge ', 'Charles ', 'Darwin ', 'Darwin ', 'Beagle ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 13
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['It is , in other words , the sense of causal relations between entities , a feeling of being influenced ']
# Right: []
# Influencers: []
# Influenced: ['It ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Henry Stapp and David Bohm are among those whose work has been influenced ']
# Right: ["influenced by Whitehead.In the 21 st century , Whiteheadian thought is still a stimulating influence : Timothy E. Eastman and Hank Keeton 's Physics and Whitehead ( 2004 ) and Michael Epperson 's Quantum Mechanics and the Philosophy of Alfred North Whitehead ( 2004 ) and Foundations of Relational Realism : A Topological Approach to Quantum Mechanics and the Philosophy of Nature ( 2013 ) , aim to offer Whiteheadian approaches to physics ."]
# Influencers: ['In ', 'Whiteheadian ', 'Timothy ', 'Eastman ', 'Hank ', 'Keeton ', 'Physics ', 'Whitehead ', 'Michael ', 'Epperson ', 'Quantum ', 'Mechanics ', 'Philosophy ', 'Alfred ', 'North ', 'Whitehead ', 'Foundations ', 'Relational ', 'Realism ', 'Topological ', 'Approach ', 'Quantum ', 'Mechanics ', 'Philosophy ', 'Nature ', 'Whiteheadian ']
# Influenced: ['Henry ', 'Stapp ', 'David ', 'Bohm ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 3
# Left: ['The teacher by whom William was most influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ', 'William ']
# Left: ['Consequently , William was one of the first theologians to be influenced ']
# Right: ['influenced by Aristotle .']
# Influencers: ['Aristotle ']
# Influenced: ['Consequently ', 'William ']
# Left: ['Summa Aurea influenced ']
# Right: []
# Influencers: []
# Influenced: ['Summa ', 'Aurea ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['This work influenced ']
# Right: []
# Influencers: []
# Influenced: ['This ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 3
# Left: ['He was influenced ']
# Right: ['influenced by his colleagues Rush Rhees and Roy Holland , both experts in the philosophy of Ludwig Wittgenstein .']
# Influencers: ['Rush ', 'Rhees ', 'Roy ', 'Holland ', 'Ludwig ', 'Wittgenstein ']
# Influenced: ['He ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['He was influenced ']
# Right: ['influenced by G.E .']
# Influencers: []
# Influenced: ['He ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Although he was a proponent of Christian values , Witherspoon 's common sense approach to the public morality of civil magistrates was more influenced "]
# Right: ['influenced by the Enlightenment ethics of Scottish philosophers Francis Hutcheson and Thomas Reid than the Christian idealism of Jonathan Edwards .']
# Influencers: ['Enlightenment ', 'Scottish ', 'Francis ', 'Hutcheson ', 'Thomas ', 'Reid ', 'Christian ', 'Jonathan ', 'Edwards ']
# Influenced: ['Although ', 'Christian ', 'Witherspoon ']
# 10
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Influence of Otto Weininger === While a student at the Realschule , Wittgenstein was influenced ']
# Right: ["influenced by Austrian philosopher Otto Weininger 's 1903 book Geschlecht und Charakter ( Sex and Character ) ."]
# Influencers: ['Austrian ', 'Otto ', 'Weininger ', 'Geschlecht ', 'Charakter ', 'Sex ', 'Character ']
# Influenced: ['Influence ', 'Otto ', 'Weininger ', 'While ', 'Realschule ', 'Wittgenstein ']
# Left: ['The extent to which The Gospel in Brief influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ', 'The ', 'Gospel ', 'Brief ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['In light of the fact that much of Wodeham ’ s work supported Ockham ’ s thought , it seems that Wodeham ’ s views were greatly influenced ']
# Right: ['influenced by his interactions with Ockham .']
# Influencers: ['Ockham ']
# Influenced: ['In ', 'Wodeham ', 'Ockham ', 'Wodeham ']
# 1
# Left: ["Wolff was read by Kierkegaard 's father Michael Pedersen , and his son himself was influenced "]
# Right: ["influenced by both Wolff and Kant to the point of resuming the tripartite structure and philosophical content to formulate his own three Stages on Life 's Way.Practical philosophy is subdivided into ethics , economics and politics ."]
# Influencers: ['Wolff ', 'Kant ', 'Stages ', 'Life ', 'Practical ']
# Influenced: ['Wolff ', 'Kierkegaard ', 'Michael ', 'Pedersen ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 5
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['It influenced ']
# Right: []
# Influencers: []
# Influenced: ['It ']
# 2
# Left: ['Thought == While an undergraduate at Calvin College , Wolterstorff was greatly influenced ']
# Right: ['influenced by professors William Harry Jellema , Henry Stob , and Henry Zylstra , who introduced him to schools of thought that have dominated his mature thinking : Reformed theology and common sense philosophy .']
# Influencers: ['William ', 'Harry ', 'Jellema ', 'Henry ', 'Stob ', 'Henry ', 'Zylstra ', 'Reformed ']
# Influenced: ['Thought ', 'While ', 'Calvin ', 'College ', 'Wolterstorff ']
# Left: ['These have also influenced ']
# Right: []
# Influencers: []
# Influenced: ['These ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["His claim that scientific principles are `` working hypotheses '' influenced "]
# Right: []
# Influencers: []
# Influenced: ['His ']
# 13
# Left: ["Career in Zurich and Leipzig === In 1875 , Wundt was promoted to professor of `` Inductive Philosophy '' in Zurich , and in 1875 , Wundt was made professor of philosophy at the University of Leipzig where Ernst Heinrich Weber ( 1795–1878 ) and Gustav Theodor Fechner ( 1801–1887 ) had initiated research on sensory psychology and psychophysics – and where two centuries earlier Gottfried Wilhelm Leibniz had developed his philosophy and theoretical psychology , which strongly influenced "]
# Right: []
# Influencers: []
# Influenced: ['Career ', 'Zurich ', 'Leipzig ', 'In ', 'Wundt ', 'Inductive ', 'Philosophy ', 'Zurich ', 'Wundt ', 'University ', 'Leipzig ', 'Ernst ', 'Heinrich ', 'Weber ', 'Gustav ', 'Theodor ', 'Fechner ', 'Gottfried ', 'Wilhelm ', 'Leibniz ']
# Left: ["He also soon revised his initial assumptions about unconscious judgements When Wundt rejects the assumption of `` the unconscious '' he is also showing his scepticism regarding Fechner 's theory of the unconscious and Wundt is perhaps even more greatly influenced "]
# Right: ['influenced by the flood of writing at the time on hypnotism and spiritualism ( Wundt , 1879 , 1892 ) .']
# Influencers: ['Wundt ']
# Influenced: ['He ', 'When ', 'Wundt ', 'Fechner ', 'Wundt ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["The central theme of `` unity in the manifold '' ( unitas in multitudine ) also originates from Leibniz , who has influenced "]
# Right: []
# Influencers: []
# Influenced: ['The ', 'Leibniz ']
# Left: ['But there are indications that George Herbert Mead and Franz Boas , among others , were influenced ']
# Right: ['influenced by it .']
# Influencers: []
# Influenced: ['But ', 'George ', 'Herbert ', 'Mead ', 'Franz ', 'Boas ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Wundt further influenced ']
# Right: []
# Influencers: []
# Influenced: ['Wundt ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['He was a close associate of the official and philosopher Huan Tan ( d. 28 CE ) , an Old Texts realist who may have heavily influenced ']
# Right: []
# Influencers: []
# Influenced: ['He ', 'Huan ', 'Tan ', 'Old ', 'Texts ']
# 1
# Left: ['His courtesy name was Gyeongho.Some of his writings were looted by the Japanese military during the Japanese invasion of Korea , which also influenced ']
# Right: []
# Influencers: []
# Influenced: ['His ', 'Some ', 'Japanese ', 'Japanese ', 'Korea ']
# 6
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Aside from Spengler , he was heavily influenced ']
# Right: ['influenced by the ideas of German legal scholar Carl Schmitt .']
# Influencers: ['German ', 'Carl ', 'Schmitt ']
# Influenced: ['Aside ', 'Spengler ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["He had a much greater impact in Europe , where intellectuals of the Right , especially the current of thought sometimes called the European New Right , including the Belgian Jean Thiriart , the Russian Aleksandr Dugin , and French writers Alain de Benoist and Guillaume Faye , adopted positions similar to Yockey 's , although there is little evidence his work influenced "]
# Right: []
# Influencers: []
# Influenced: ['He ', 'Europe ', 'Right ', 'European ', 'New ', 'Right ', 'Belgian ', 'Jean ', 'Thiriart ', 'Russian ', 'Aleksandr ', 'Dugin ', 'French ', 'Alain ', 'Benoist ', 'Guillaume ', 'Faye ', 'Yockey ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['He has influenced ']
# Right: []
# Influencers: []
# Influenced: ['He ']
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 18
# Left: ['He had a Chinese nationalist and an anti-imperialist outlook early in his life , and was particularly influenced ']
# Right: ['influenced by the events of the Xinhai Revolution of 1911 and May Fourth Movement of 1919 .']
# Influencers: ['Xinhai ', 'Revolution ', 'May ', 'Fourth ', 'Movement ']
# Influenced: ['He ', 'Chinese ']
# Left: ['In Changsha , Mao was influenced ']
# Right: ["influenced by Sun 's newspaper , The People 's Independence ( Minli bao ) , and called for Sun to become president in a school essay ."]
# Influencers: ['Sun ', 'The ', 'People ', 'Independence ', 'Minli ', 'Sun ']
# Influenced: ['In ', 'Changsha ', 'Mao ']
# Left: ["Becoming `` more and more radical '' , Mao was initially influenced "]
# Right: ["influenced by Peter Kropotkin 's anarchism , which was the most prominent radical doctrine of the day ."]
# Influencers: ['Peter ', 'Kropotkin ']
# Influenced: ['Becoming ', 'Mao ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['His ideas were not Marxist , but heavily influenced ']
# Right: ["influenced by Kropotkin 's concept of mutual aid ."]
# Influencers: ['Kropotkin ']
# Influenced: ['His ', 'Marxist ']
# Left: ['Several of these advocated feminist views , calling for the liberation of women in Chinese society ; Mao was influenced ']
# Right: ['influenced by his forced arranged-marriage .']
# Influencers: []
# Influenced: ['Several ', 'Chinese ', 'Mao ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['Outnumbered , Mao responded with guerrilla tactics influenced ']
# Right: ['influenced by the works of ancient military strategists like Sun Tzu , but Zhou and the new leadership followed a policy of open confrontation and conventional warfare .']
# Influencers: ['Sun ', 'Tzu ', 'Zhou ']
# Influenced: ['Outnumbered ', 'Mao ']
# Left: ['The split helped to determine the framework of the Second Cold War in general , and influenced ']
# Right: []
# Influencers: []
# Influenced: ['The ', 'Second ', 'Cold ', 'War ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["The official Chinese translation of President Barack Obama 's inauguration speech used a famous line from one of Mao 's poems.The ideology of Maoism has influenced "]
# Right: []
# Influencers: []
# Influenced: ['The ', 'Chinese ', 'President ', 'Barack ', 'Obama ', 'Mao ', 'The ', 'Maoism ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Mao 's granddaughter , Kong Dongmei , defended the phenomenon , stating that `` it shows his influence , that he exists in people 's consciousness and has influenced "]
# Right: []
# Influencers: []
# Influenced: ['Mao ', 'Kong ', 'Dongmei ']
# Left: ['His style was influenced ']
# Right: ['influenced by the great Tang dynasty poets Li Bai and Li He .']
# Influencers: ['Tang ', 'Li ', 'Bai ', 'Li ', 'He ']
# Influenced: ['His ']
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ["Zeller 's conception of the history of Greek thought was influenced "]
# Right: ['influenced by the dialectical philosophy of Hegel .']
# Influencers: ['Hegel ']
# Influenced: ['Zeller ', 'Greek ']
# 3
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: ['But his general views can be outlined as follows : === Logic === In his treatment of Logic , Zeno was influenced ']
# Right: ['influenced by Stilpo and the other Megarians .']
# Influencers: ['Stilpo ', 'Megarians ']
# Influenced: ['But ', 'Logic ', 'In ', 'Logic ', 'Zeno ']
# 1
# Left: ["Zeno 's paradoxes == Zeno 's paradoxes have puzzled , challenged , influenced "]
# Right: []
# Influencers: []
# Influenced: ['Zeno ', 'Zeno ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 2
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ['Influence == Zhuangzi has influenced ']
# Right: []
# Influencers: []
# Influenced: ['Influence ', 'Zhuangzi ']
# 1
# Left: []
# Right: []
# Influencers: []
# Influenced: []
# 1
# Left: ["Themes == === Empirical sociology === Znaniecki 's contributions to empirical sociology began after , and were influenced "]
# Right: ['influenced by , his collaboration with William I. Thomas .']
# Influencers: ['William ', 'Thomas ']
# Influenced: ['Themes ', 'Empirical ', 'Znaniecki ']

# %% [markdown]
# # ***Processing Luigi(Regex)***

# %%
"""
Input cella:
jsonlist = 
[
    {
        "philosopher" = "philosopher_name",
        "pageid" = id,
        "article" = 
        [
            "frase contenente influence",

            "frase contenente influence", etc
        ]
    }
]

Output cella:
output =
[
    {
        "philosopher" = "philosopher_name",
        "pageid" = id,
        "article" = 
        [
            [
                "frase contenente influence",
                [
                    list of influencers
                ],
                [
                    list of influenced
                ]
        ]
    }
]
"""

"""
#some prints and infos

#pprint.pprint(jsonlist)
print(len(jsonlist))
jsonlist_no_empty = [i for i in jsonlist if len(i["article"]) != 0]
print(len(jsonlist_no_empty))
print([[i["philosopher"], len(i["article"]), i["article"]] for i in jsonlist_no_empty if i["philosopher"] == "Socrates"])
"""
